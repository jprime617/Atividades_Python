# %%
import random

# %%
Gundam_lista = [
    "Wing Gundam (Bird Mode)",
    "Gundam Heavyarms",
    "Gundam Sandrock",
    "Maganac",
    "Leo",
    "Aries",
    "Tragos",
    "RX-78-2 Gundam",
    "RX-78-2 Gundam (MA Form)",
    "Guncannon",
    "Guntank",
    "GM RGM-79",
    "Gundam Aerial (Permet Score Six)",
    "Gundam Aerial (Bit on Form)",
    "Demi Trainer MSJ-121",
    "Zowort F/O-19",
    "Aile Strike Gundam",
    "Strike Gundam",
    "Moebius Zero",
    "Moebius",
    "Strike Dagger",
    "Aegis Gundam (MA Mode)",
    "Ginn",
    "Miguel’s Ginn",
]

# %%
lista1 = [
    {"Nome": "Wing Gundam", "Atk": 14, "Def": 2, "Spd": 19},
    {"Nome": "Gundam Heavyarms", "Atk": 6, "Def": 3, "Spd": 18},
    {"Nome": "Gundam Sandrock", "Atk": 8, "Def": 12, "Spd": 4},
    {"Nome": "Gundam Aerial", "Atk": 5, "Def": 7, "Spd": 11},
    {"Nome": "Gundam Aerial Rebuild", "Atk": 17, "Def": 10, "Spd": 13},
    {"Nome": "RX-78-2 Gundam", "Atk": 9, "Def": 1, "Spd": 16},
    {"Nome": "Zeta Gundam", "Atk": 15, "Def": 4, "Spd": 20},
    {"Nome": "ZZ Gundam", "Atk": 3, "Def": 18, "Spd": 6},
    {"Nome": "Unicorn Gundam", "Atk": 11, "Def": 14, "Spd": 8},
    {"Nome": "Banshee Norn", "Atk": 2, "Def": 19, "Spd": 7},
    {"Nome": "Strike Gundam", "Atk": 12, "Def": 5, "Spd": 9},
    {"Nome": "Freedom Gundam", "Atk": 7, "Def": 13, "Spd": 1},
    {"Nome": "Justice Gundam", "Atk": 18, "Def": 11, "Spd": 15},
    {"Nome": "Destiny Gundam", "Atk": 20, "Def": 9, "Spd": 12},
    {"Nome": "Barbatos", "Atk": 4, "Def": 6, "Spd": 17},
    {"Nome": "Barbatos Lupus Rex", "Atk": 10, "Def": 8, "Spd": 2},
    {"Nome": "Gundam Exia", "Atk": 13, "Def": 16, "Spd": 5},
    {"Nome": "Gundam Dynames", "Atk": 1, "Def": 20, "Spd": 14},
    {"Nome": "Gundam Kyrios", "Atk": 16, "Def": 7, "Spd": 3},
    {"Nome": "Gundam Virtue", "Atk": 19, "Def": 15, "Spd": 10},
]

lista2 = [
    {"Nome": "Turn A Gundam", "Atk": 3, "Def": 11, "Spd": 18},
    {"Nome": "Turn X", "Atk": 7, "Def": 19, "Spd": 9},
    {"Nome": "Gundam 00 Raiser", "Atk": 14, "Def": 5, "Spd": 2},
    {"Nome": "Gundam Harute", "Atk": 6, "Def": 17, "Spd": 12},
    {"Nome": "Gundam Zabanya", "Atk": 1, "Def": 20, "Spd": 8},
    {"Nome": "Gundam Seravee II", "Atk": 13, "Def": 4, "Spd": 16},
    {"Nome": "Strike Freedom Gundam", "Atk": 10, "Def": 15, "Spd": 6},
    {"Nome": "Infinite Justice Gundam", "Atk": 8, "Def": 12, "Spd": 19},
    {"Nome": "Gundam Kimaris", "Atk": 5, "Def": 9, "Spd": 14},
    {"Nome": "Gundam Bael", "Atk": 17, "Def": 2, "Spd": 7},
    {"Nome": "Gundam AGE-1", "Atk": 20, "Def": 13, "Spd": 11},
    {"Nome": "Gundam AGE-2", "Atk": 16, "Def": 8, "Spd": 3},
    {"Nome": "Gundam AGE-3", "Atk": 12, "Def": 6, "Spd": 15},
    {"Nome": "Gundam AGE-FX", "Atk": 9, "Def": 1, "Spd": 20},
    {"Nome": "Crossbone Gundam X1", "Atk": 18, "Def": 7, "Spd": 10},
    {"Nome": "Crossbone Gundam X2", "Atk": 2, "Def": 16, "Spd": 4},
    {"Nome": "Crossbone Gundam X3", "Atk": 11, "Def": 14, "Spd": 5},
    {"Nome": "Gundam F91", "Atk": 15, "Def": 18, "Spd": 9},
    {"Nome": "V2 Gundam", "Atk": 4, "Def": 3, "Spd": 17},
    {"Nome": "G-Self", "Atk": 19, "Def": 10, "Spd": 13},
]



for i in lista1:
    print(i["Nome"])
# Out:
# Wing Gundam
# Gundam Heavyarms
# Gundam Sandrock
# Gundam Aerial
# Gundam Aerial Rebuild
# RX-78-2 Gundam
# Zeta Gundam
# ZZ Gundam
# Unicorn Gundam
# Banshee Norn
# Strike Gundam
# Freedom Gundam
# Justice Gundam
# Destiny Gundam
# Barbatos
# Barbatos Lupus Rex
# Gundam Exia
# Gundam Dynames
# Gundam Kyrios
# Gundam Virtue

# %%
class Carta:
    def __init__(self, name, atk, defe, spd):
        self.Name = name
        self.Atk = atk
        self.Def = defe
        self.Spd = spd
        
Pilha = []
Pilha2 = []

Fila = []
Fila2 = []

def seila():
    for i in lista1:
        Pilha.append(Carta(i["Nome"], i["Atk"], i["Def"], i["Spd"]))
        

    for i in lista2:
        Pilha2.append(Carta(i["Nome"] + " Enemy", i["Atk"], i["Def"], i["Spd"]))

# %%
# def Ordenar(X):
#     for i in X:
#         n = 0
#         if i.Spd > n:
#             carta = X.pop(i)
#             X.append(carta)
#         n = i

# %%
def Adicionar():
    while len(Fila) < 5 and Pilha:
        Fila.append(Pilha.pop(-1))
        

    while len(Fila2) < 5 and Pilha2:
        Fila2.append(Pilha2.pop(-1))

# %%
def Batalha():
    while Fila and Fila2:  # enquanto houver cartas nas filas
        carta1 = Fila.pop(0)
        carta2 = Fila2.pop(0)

        Adicionar()

        print("\n=== Novo Duelo ===")
        print(f"JOGADOR: {carta1.Name} | ATK:{carta1.Atk} DEF:{carta1.Def} SPD:{carta1.Spd}")
        print(f"ENEMY:   {carta2.Name} | ATK:{carta2.Atk} DEF:{carta2.Def} SPD:{carta2.Spd}")
        print("--------------------------------------------------")

        # combate até alguém perder
        while carta1.Def > 0 and carta2.Def > 0:
            if carta1.Spd >= carta2.Spd:  
                # jogador ataca primeiro
                carta2.Def -= carta1.Atk
                if carta2.Def <= 0:
                    break
                carta1.Def -= carta2.Atk
            else:
                # inimigo ataca primeiro
                carta1.Def -= carta2.Atk
                if carta1.Def <= 0:
                    break
                carta2.Def -= carta1.Atk

        # resultado
        if carta1.Def > 0 and carta2.Def <= 0:
            print("================ JOGADOR VENCEU ================")
        elif carta2.Def > 0 and carta1.Def <= 0:
            print("================ ENEMY VENCEU =================")
        else:
            print("================ EMPATE =======================")

        
        print("//////////////////////////////////////////////////")

# %%
seila()
Adicionar()
Batalha()
# Out:
# === Novo Duelo ===
# JOGADOR: Gundam Virtue | ATK:19 DEF:15 SPD:10
# ENEMY:   G-Self Enemy | ATK:19 DEF:10 SPD:13
# --------------------------------------------------
# ================ ENEMY VENCEU =================
# //////////////////////////////////////////////////
#
# === Novo Duelo ===
# JOGADOR: Gundam Kyrios | ATK:16 DEF:7 SPD:3
# ENEMY:   V2 Gundam Enemy | ATK:4 DEF:3 SPD:17
# --------------------------------------------------
# ================ JOGADOR VENCEU ================
# //////////////////////////////////////////////////
#
# === Novo Duelo ===
# JOGADOR: Gundam Dynames | ATK:1 DEF:20 SPD:14
# ENEMY:   Gundam F91 Enemy | ATK:15 DEF:18 SPD:9
# --------------------------------------------------
# ================ ENEMY VENCEU =================
# //////////////////////////////////////////////////
#
# === Novo Duelo ===
# JOGADOR: Gundam Exia | ATK:13 DEF:16 SPD:5
# ENEMY:   Crossbone Gundam X3 Enemy | ATK:11 DEF:14 SPD:5
# ...
